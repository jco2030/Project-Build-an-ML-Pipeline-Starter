# %%
# !pip install wandb==0.16.0
# !pip install ydata-profiling==4.12.1
# !pip install pandas==2.1.3
# Out:
# Collecting wandb==0.16.0
#   Downloading wandb-0.16.0-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 14.4 MB/s eta 0:00:0000:010:01
# Collecting protobuf!=4.21.0,<5,>=3.19.0
#   Downloading protobuf-4.25.9-cp37-abi3-manylinux2014_x86_64.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.2/295.2 kB 34.1 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /opt/venv/lib/python3.10/site-packages (from wandb==0.16.0) (6.1.0)
# Collecting GitPython!=3.1.29,>=1.0.0
#   Downloading gitpython-3.1.62-py3-none-any.whl (222 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 222.8/222.8 kB 28.3 MB/s eta 0:00:00
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-2.70.0-py3-none-any.whl (531 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 531.8/531.8 kB 49.2 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /opt/venv/lib/python3.10/site-packages (from wandb==0.16.0) (65.5.0)
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting Click!=8.0.0,>=7.1
#   Downloading click-8.5.0-py3-none-any.whl (125 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.3/125.3 kB 21.5 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML in /opt/venv/lib/python3.10/site-packages (from wandb==0.16.0) (6.0.2)
# Collecting setproctitle
#   Downloading setproctitle-1.3.7-cp310-cp310-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (31 kB)
# Collecting appdirs>=1.4.3
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting requests<3,>=2.0.0
#   Downloading requests-2.34.2-py3-none-any.whl (73 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: six>=1.4.0 in /opt/venv/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb==0.16.0) (1.17.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 10.3 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb==0.16.0) (3.10)
# Collecting charset_normalizer<4,>=2
#   Downloading charset_normalizer-3.5.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (261 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 261.6/261.6 kB 36.8 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.26
#   Downloading urllib3-2.8.0-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.7/135.7 kB 21.0 MB/s eta 0:00:00
# Collecting certifi>=2023.5.7
#   Downloading certifi-2026.7.22-py3-none-any.whl (136 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.0/137.0 kB 22.9 MB/s eta 0:00:00
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.3-py3-none-any.whl (24 kB)
# Installing collected packages: appdirs, urllib3, smmap, setproctitle, protobuf, docker-pycreds, Click, charset_normalizer, certifi, sentry-sdk, requests, gitdb, GitPython, wandb
# Successfully installed Click-8.5.0 GitPython-3.1.62 appdirs-1.4.4 certifi-2026.7.22 charset_normalizer-3.5.1 docker-pycreds-0.4.0 gitdb-4.0.12 protobuf-4.25.9 requests-2.34.2 sentry-sdk-2.70.0 setproctitle-1.3.7 smmap-5.0.3 urllib3-2.8.0 wandb-0.16.0
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Collecting ydata-profiling==4.12.1
#   Downloading ydata_profiling-4.12.1-py2.py3-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.9/390.9 kB 4.4 MB/s eta 0:00:0000:0100:01
# Collecting numba<1,>=0.56.0
#   Downloading numba-0.67.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 45.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: numpy<2.2,>=1.16.0 in /opt/venv/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (1.26.3)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.5-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (677 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.6/677.6 kB 61.2 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in /opt/venv/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (6.0.2)
# Requirement already satisfied: scipy<1.14,>=1.4.1 in /opt/venv/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (1.11.4)
# Collecting typeguard<5,>=3
#   Downloading typeguard-4.6.0-py3-none-any.whl (36 kB)
# Collecting pydantic>=2
#   Downloading pydantic-2.13.5-py3-none-any.whl (472 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.6/472.6 kB 50.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas!=1.4.0,<3,>1.1 in /opt/venv/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (2.1.4)
# Collecting wordcloud>=1.9.3
#   Downloading wordcloud-1.9.6-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (526 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 526.2/526.2 kB 48.2 MB/s eta 0:00:00
# Requirement already satisfied: statsmodels<1,>=0.13.2 in /opt/venv/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (0.14.1)
# Collecting visions[type_image_path]<0.7.7,>=0.7.5
#   Downloading visions-0.7.6-py3-none-any.whl (104 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 104.8/104.8 kB 17.6 MB/s eta 0:00:00
# Collecting multimethod<2,>=1.4
#   Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Requirement already satisfied: requests<3,>=2.24.0 in /opt/venv/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (2.34.2)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in /opt/venv/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (3.1.4)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in /opt/venv/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (0.13.1)
# Collecting tqdm<5,>=4.48.2
#   Downloading tqdm-4.70.1-py3-none-any.whl (80 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.2/80.2 kB 6.1 MB/s eta 0:00:00
# Collecting dacite>=1.8
#   Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Collecting imagehash==4.3.1
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.5/296.5 kB 46.6 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib<3.10,>=3.5 in /opt/venv/lib/python3.10/site-packages (from ydata-profiling==4.12.1) (3.8.2)
# Collecting htmlmin==0.1.12
#   Downloading htmlmin-0.1.12.tar.gz (19 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pillow in /opt/venv/lib/python3.10/site-packages (from imagehash==4.3.1->ydata-profiling==4.12.1) (10.2.0)
# Collecting PyWavelets
#   Downloading pywavelets-1.8.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 105.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/venv/lib/python3.10/site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling==4.12.1) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/venv/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.3.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/venv/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/venv/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (3.2.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/venv/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (4.55.2)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/venv/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (2.9.0.post0)
# Requirement already satisfied: packaging>=20.0 in /opt/venv/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (24.2)
# Requirement already satisfied: cycler>=0.10 in /opt/venv/lib/python3.10/site-packages (from matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (0.12.1)
# Collecting llvmlite<0.50,>=0.49.0dev0
#   Downloading llvmlite-0.49.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (59.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.9/59.9 MB 28.1 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: tzdata>=2022.1 in /opt/venv/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2024.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.10/site-packages (from pandas!=1.4.0,<3,>1.1->ydata-profiling==4.12.1) (2024.2)
# Requirement already satisfied: joblib>=0.14.1 in /opt/venv/lib/python3.10/site-packages (from phik<0.13,>=0.11.1->ydata-profiling==4.12.1) (1.4.2)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.8.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.46.5
#   Downloading pydantic_core-2.46.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 86.1 MB/s eta 0:00:00
# Collecting typing-inspection>=0.4.2
#   Downloading typing_inspection-0.4.4-py3-none-any.whl (14 kB)
# Collecting typing-extensions>=4.14.1
#   Downloading typing_extensions-4.16.0-py3-none-any.whl (45 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.10)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (3.5.1)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2026.7.22)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.24.0->ydata-profiling==4.12.1) (2.8.0)
# Requirement already satisfied: patsy>=0.5.4 in /opt/venv/lib/python3.10/site-packages (from statsmodels<1,>=0.13.2->ydata-profiling==4.12.1) (1.0.1)
# Collecting networkx>=2.4
#   Downloading networkx-3.4.2-py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 95.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=19.3.0 in /opt/venv/lib/python3.10/site-packages (from visions[type_image_path]<0.7.7,>=0.7.5->ydata-profiling==4.12.1) (24.2.0)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib<3.10,>=3.5->ydata-profiling==4.12.1) (1.17.0)
# Installing collected packages: htmlmin, typing-extensions, tqdm, PyWavelets, networkx, multimethod, llvmlite, dacite, annotated-types, typing-inspection, typeguard, pydantic-core, numba, imagehash, wordcloud, visions, pydantic, phik, ydata-profiling
#   DEPRECATION: htmlmin is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for htmlmin ... done
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.12.2
#     Uninstalling typing_extensions-4.12.2:
#       Successfully uninstalled typing_extensions-4.12.2
# Successfully installed PyWavelets-1.8.0 annotated-types-0.8.0 dacite-1.9.2 htmlmin-0.1.12 imagehash-4.3.1 llvmlite-0.49.0 multimethod-1.12 networkx-3.4.2 numba-0.67.0 phik-0.12.5 pydantic-2.13.5 pydantic-core-2.46.5 tqdm-4.70.1 typeguard-4.6.0 typing-extensions-4.16.0 typing-inspection-0.4.4 visions-0.7.6 wordcloud-1.9.6 ydata-profiling-4.12.1
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Collecting pandas==2.1.3
#   Downloading pandas-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 77.0 MB/s eta 0:00:0000:010:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/venv/lib/python3.10/site-packages (from pandas==2.1.3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/venv/lib/python3.10/site-packages (from pandas==2.1.3) (2024.2)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/venv/lib/python3.10/site-packages (from pandas==2.1.3) (1.26.3)
# Requirement already satisfied: tzdata>=2022.1 in /opt/venv/lib/python3.10/site-packages (from pandas==2.1.3) (2024.2)
# Requirement already satisfied: six>=1.5 in /opt/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.1.3) (1.17.0)
# Installing collected packages: pandas
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.1.4
#     Uninstalling pandas-2.1.4:
#       Successfully uninstalled pandas-2.1.4
# Successfully installed pandas-2.1.3
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# 1. Fetch the artifact we just created (sample.csv) from W&B and read it with pandas:

# %%
# !pip install --upgrade wandb
# Out:
# Requirement already satisfied: wandb in /opt/venv/lib/python3.10/site-packages (0.16.0)
# Collecting wandb
#   Downloading wandb-0.30.0-py3-none-manylinux_2_28_x86_64.whl (26.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 59.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: packaging in /opt/venv/lib/python3.10/site-packages (from wandb) (24.2)
# Collecting opentelemetry-sdk>=1.43.0
#   Downloading opentelemetry_sdk-1.44.0-py3-none-any.whl (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 24.9 MB/s eta 0:00:00
# Collecting xxhash>=3.0.0
#   Downloading xxhash-4.0.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (249 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 249.5/249.5 kB 33.1 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml in /opt/venv/lib/python3.10/site-packages (from wandb) (6.0.2)
# Collecting protobuf!=5.28.0,!=5.29.0,<8,>=5
#   Downloading protobuf-7.36.2-cp310-abi3-manylinux2014_x86_64.whl (343 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 343.2/343.2 kB 37.3 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3,>=2.6 in /opt/venv/lib/python3.10/site-packages (from wandb) (2.13.5)
# Requirement already satisfied: platformdirs in /opt/venv/lib/python3.10/site-packages (from wandb) (4.3.6)
# Requirement already satisfied: typing-extensions<5,>=4.8 in /opt/venv/lib/python3.10/site-packages (from wandb) (4.16.0)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/venv/lib/python3.10/site-packages (from wandb) (2.34.2)
# Collecting opentelemetry-api>=1.43.0
#   Downloading opentelemetry_api-1.44.0-py3-none-any.whl (60 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: click>=8.2.0 in /opt/venv/lib/python3.10/site-packages (from wandb) (8.5.0)
# Collecting opentelemetry-exporter-otlp-proto-http>=1.43.0
#   Downloading opentelemetry_exporter_otlp_proto_http-1.44.0-py3-none-any.whl (21 kB)
# Collecting opentelemetry-proto==1.44.0
#   Downloading opentelemetry_proto-1.44.0-py3-none-any.whl (72 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 12.5 MB/s eta 0:00:00
# Collecting googleapis-common-protos~=1.52
#   Downloading googleapis_common_protos-1.75.3-py3-none-any.whl (306 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 45.5 MB/s eta 0:00:00
# Collecting opentelemetry-exporter-otlp-proto-common==1.44.0
#   Downloading opentelemetry_exporter_otlp_proto_common-1.44.0-py3-none-any.whl (17 kB)
# Collecting opentelemetry-semantic-conventions==0.65b0
#   Downloading opentelemetry_semantic_conventions-0.65b0-py3-none-any.whl (204 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/venv/lib/python3.10/site-packages (from pydantic<3,>=2.6->wandb) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /opt/venv/lib/python3.10/site-packages (from pydantic<3,>=2.6->wandb) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /opt/venv/lib/python3.10/site-packages (from pydantic<3,>=2.6->wandb) (0.4.4)
# Requirement already satisfied: certifi>=2023.5.7 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2026.7.22)
# Requirement already satisfied: urllib3<3,>=1.26 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2.8.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.5.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/venv/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.10)
# Installing collected packages: xxhash, protobuf, opentelemetry-api, opentelemetry-semantic-conventions, opentelemetry-proto, googleapis-common-protos, opentelemetry-sdk, opentelemetry-exporter-otlp-proto-common, opentelemetry-exporter-otlp-proto-http, wandb
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.25.9
#     Uninstalling protobuf-4.25.9:
#       Successfully uninstalled protobuf-4.25.9
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.16.0
#     Uninstalling wandb-0.16.0:
#       Successfully uninstalled wandb-0.16.0
# Successfully installed googleapis-common-protos-1.75.3 opentelemetry-api-1.44.0 opentelemetry-exporter-otlp-proto-common-1.44.0 opentelemetry-exporter-otlp-proto-http-1.44.0 opentelemetry-proto-1.44.0 opentelemetry-sdk-1.44.0 opentelemetry-semantic-conventions-0.65b0 protobuf-7.36.2 wandb-0.30.0 xxhash-4.0.1
#
# [notice] A new release of pip is available: 23.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip

# %%
import wandb
import pandas as pd
# Note that we use save_code=True in the call to wandb.init so the notebook is uploaded and versioned by W&B
run = wandb.init(project="nyc_airbnb", group="eda", save_code=True)
local_path = wandb.use_artifact("sample.csv:latest").file()
df = pd.read_csv(local_path)
# Out:
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice: 2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Create a new API key at: https://wandb.ai/authorize?ref=models
# wandb: Store your API key securely and do not share it.
# wandb: Paste your API key and hit enter: ········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/student/.netrc
# wandb: Currently logged in as: jco2030 (jco2030-western-governors-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.30.0
# Run data is saved locally in <code>/workspace/Project-Build-an-ML-Pipeline-Starter/src/eda/wandb/run-20260923_204829-ooz2nay8</code>
# Syncing run <strong><a href='https://wandb.ai/jco2030-western-governors-university/nyc_airbnb/runs/ooz2nay8' target="_blank">visionary-firefly-3</a></strong> to <a href='https://wandb.ai/jco2030-western-governors-university/nyc_airbnb' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/jco2030-western-governors-university/nyc_airbnb' target="_blank">https://wandb.ai/jco2030-western-governors-university/nyc_airbnb</a>
#  View run at <a href='https://wandb.ai/jco2030-western-governors-university/nyc_airbnb/runs/ooz2nay8' target="_blank">https://wandb.ai/jco2030-western-governors-university/nyc_airbnb/runs/ooz2nay8</a>

# %% [markdown]
# 2. Explore the data in df

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              20000 non-null  int64
#  1   name                            19993 non-null  object
#  2   host_id                         20000 non-null  int64
#  3   host_name                       19992 non-null  object
#  4   neighbourhood_group             20000 non-null  object
#  5   neighbourhood                   20000 non-null  object
#  6   latitude                        20000 non-null  float64
#  7   longitude                       20000 non-null  float64
#  8   room_type                       20000 non-null  object
#  9   price                           20000 non-null  int64
#  10  minimum_nights                  20000 non-null  int64
#  11  number_of_reviews               20000 non-null  int64
#  12  last_review                     15877 non-null  object
#  13  reviews_per_month               15877 non-null  float64
#  14  calculated_host_listings_count  20000 non-null  int64
#  15  availability_365                20000 non-null  int64
# dtypes: float64(3), int64(7), object(6)
# memory usage: 2.4+ MB

# %%
df.describe()
# Out:
#                  id       host_id      latitude     longitude         price  \
# count  2.000000e+04  2.000000e+04  20000.000000  20000.000000  20000.000000
# mean   1.892380e+07  6.746034e+07     40.728455    -73.952125    153.269050
# std    1.101223e+07  7.857936e+07      0.054755      0.046559    243.325609
# min    2.539000e+03  2.571000e+03     40.508730    -74.239140      0.000000
# 25%    9.393540e+06  7.853718e+06     40.689420    -73.983030     69.000000
# 50%    1.952117e+07  3.111431e+07     40.722730    -73.955640    105.000000
# 75%    2.912936e+07  1.068426e+08     40.762990    -73.936380    175.000000
# max    3.648561e+07  2.742733e+08     40.913060    -73.717950  10000.000000
#
#        minimum_nights  number_of_reviews  reviews_per_month  \
# count    20000.000000       20000.000000       15877.000000
# mean         6.992100          23.274100           1.377446
# std         21.645449          44.927793           1.683006
# min          1.000000           0.000000           0.010000
# 25%          1.000000           1.000000           0.190000
# 50%          2.000000           5.000000           0.720000
# 75%          5.000000          23.000000           2.010000
# max       1250.000000         607.000000          27.950000
#
#        calculated_host_listings_count  availability_365
# count                    20000.000000      20000.000000
# mean                         6.955450        112.901200
# std                         32.433831        131.762226
# min                          1.000000          0.000000
# 25%                          1.000000          0.000000
# 50%                          1.000000         44.000000
# 75%                          2.000000        229.000000
# max                        327.000000        365.000000

# %%
df.head()
# Out:
#          id                                               name    host_id  \
# 0   9138664                Private Lg Room 15 min to Manhattan   47594947
# 1  31444015  TIME SQUARE CHARMING ONE BED IN HELL'S KITCHEN...    8523790
# 2   8741020  Voted #1 Location Quintessential 1BR W Village...   45854238
# 3  34602077  Spacious 1 bedroom apartment 15min from Manhattan  261055465
# 4  23203149   Big beautiful bedroom in huge Bushwick apartment     143460
#
#   host_name neighbourhood_group   neighbourhood  latitude  longitude  \
# 0      Iris              Queens       Sunnyside  40.74271  -73.92493
# 1    Johlex           Manhattan  Hell's Kitchen  40.76682  -73.98878
# 2      John           Manhattan    West Village  40.73631  -74.00611
# 3     Regan              Queens         Astoria  40.76424  -73.92351
# 4     Megan            Brooklyn        Bushwick  40.69839  -73.92044
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room     74               2                  6  2019-05-26
# 1  Entire home/apt    170               3                  0         NaN
# 2  Entire home/apt    245               3                 51  2018-09-19
# 3  Entire home/apt    125               3                  1  2019-05-24
# 4     Private room     65               2                  8  2019-06-23
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.13                               1                 5
# 1                NaN                               1               188
# 2               1.12                               1                 0
# 3               0.65                               1                13
# 4               0.52                               2                 8

# %% [markdown]
# 3. What do you notice in the data? Look around and see what you can find.
#
# > For example, there are missing values in a few columns and the column `last_review` is a date but it is in string format. Look also at the `price` column, and note the outliers. There are some zeros and some very high prices. After talking to your stakeholders, you decide to consider from a minimum of `$10` to a maximum of `$350` per night.

# %% [markdown]
# 4. Fix some of the little problems we have found in the data with the following code:

# %%
# Drop outliers
min_price = 10
max_price = 350
idx = df['price'].between(min_price, max_price)
df = df[idx].copy()
# Convert last_review to datetime
df['last_review'] = pd.to_datetime(df['last_review'])

# %% [markdown]
# Note how we did not impute missing values. We will do that in the inference pipeline, so we will be able to handle missing values also in production.

# %% [markdown]
# 5. Check with df.info() that all obvious problems have been solved

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19001 entries, 0 to 19999
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              19001 non-null  int64
#  1   name                            18994 non-null  object
#  2   host_id                         19001 non-null  int64
#  3   host_name                       18993 non-null  object
#  4   neighbourhood_group             19001 non-null  object
#  5   neighbourhood                   19001 non-null  object
#  6   latitude                        19001 non-null  float64
#  7   longitude                       19001 non-null  float64
#  8   room_type                       19001 non-null  object
#  9   price                           19001 non-null  int64
#  10  minimum_nights                  19001 non-null  int64
#  11  number_of_reviews               19001 non-null  int64
#  12  last_review                     15243 non-null  datetime64[ns]
#  13  reviews_per_month               15243 non-null  float64
#  14  calculated_host_listings_count  19001 non-null  int64
#  15  availability_365                19001 non-null  int64
# dtypes: datetime64[ns](1), float64(3), int64(7), object(5)
# memory usage: 2.5+ MB

# %% [markdown]
# 6. Terminate the run by running `run.finish()`

# %%
run.finish()
# Out:
#  View run <strong style="color:#cdcd00">visionary-firefly-3</strong> at: <a href='https://wandb.ai/jco2030-western-governors-university/nyc_airbnb/runs/ooz2nay8' target="_blank">https://wandb.ai/jco2030-western-governors-university/nyc_airbnb/runs/ooz2nay8</a><br> View project at: <a href='https://wandb.ai/jco2030-western-governors-university/nyc_airbnb' target="_blank">https://wandb.ai/jco2030-western-governors-university/nyc_airbnb</a><br>Synced 8 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20260923_204829-ooz2nay8/logs</code>

# %% [markdown]
# 7. Save the notebook.
